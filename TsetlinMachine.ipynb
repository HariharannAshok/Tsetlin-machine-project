# %% [markdown]
# <a href="https://colab.research.google.com/github/Rome0607/Tsetlin-machine-project/blob/main/TsetlinMachine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyTsetlinMachine
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pip install pyTsetlinMachine
import nltk
nltk.download('punkt')

import pandas as pd
import re
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from pyTsetlinMachine.tm import MultiClassTsetlinMachine
import numpy as np
from imblearn.over_sampling import SMOTE
from joblib import Parallel, delayed
import multiprocessing

# Load the slang dictionary from the CSV file
slang_df = pd.read_csv("final_Uk_slang.csv")
slang_dict = pd.Series(slang_df.formal_translation.values, index=slang_df.slang).to_dict()

# Define text cleaning function
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^a-z0-9\s]", "", text)
    text = text.strip()
    return text

# Define normalization function with refined handling
def normalize_text(text, slang_dict):
    words = text.split()
    normalized_words = [slang_dict.get(word, word) for word in words]
    return ' '.join(normalized_words)

# Load your sentiment dataset
data = pd.read_csv("sentiment_data.csv")  # Assuming you have a CSV file with columns 'text' and 'sentiment'

# Clean and normalize text
data['cleaned_text'] = data['text'].apply(clean_text)
data['normalized_text'] = data['cleaned_text'].apply(lambda x: normalize_text(x, slang_dict))

# Tokenize text
data['tokens'] = Parallel(n_jobs=multiprocessing.cpu_count())(delayed(word_tokenize)(text) for text in data['normalized_text'])

# Determine a fixed length for token sequences
fixed_length = 10

# Pad or truncate token sequences to the fixed length
def pad_or_truncate(tokens, length):
    if len(tokens) > length:
        return tokens[:length]
    else:
        return tokens + [''] * (length - len(tokens))

data['padded_tokens'] = data['tokens'].apply(lambda x: pad_or_truncate(x, fixed_length))

# One-hot encode tokens with improved encoding method
def one_hot_encode(tokens, encoder=None):
    encoded_tokens = encoder.transform([[token] for token in tokens])
    return encoded_tokens

# Initialize OneHotEncoder
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')

# Fit encoder on the entire vocabulary
vocab = list(set([token for sublist in data['padded_tokens'] for token in sublist if token]))
encoder.fit([[token] for token in vocab])

# Apply one-hot encoding to all tokenized texts
data['binary_features'] = Parallel(n_jobs=multiprocessing.cpu_count())(delayed(one_hot_encode)(tokens, encoder) for tokens in data['padded_tokens'])

# Ensure correct format for features
X = np.vstack(data['binary_features'].apply(lambda x: x.flatten()))
y = data['sentiment'].values  # Ensure this is numeric, e.g., 0 for negative, 1 for positive

# Initialize StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to train and evaluate model on a fold
def train_and_evaluate(train_index, test_index, X, y, encoder, data):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Balance classes using SMOTE
    smote = SMOTE(random_state=42, n_jobs=multiprocessing.cpu_count())
    X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

    # Train the model with optimized parameters
    tm = MultiClassTsetlinMachine(
        number_of_clauses=500,  # Adjust the number of clauses
        T=50,                   # Adjust the threshold
        s=10.0                  # Adjust specificity
    )
    tm.fit(X_resampled, y_resampled, epochs=30)  # Adjust epochs if needed

    # Predict on the test data
    y_pred = tm.predict(X_test)

    # Get the translated results (normalized text)
    translated_texts = data.iloc[test_index]['normalized_text'].values

    # Calculate metrics for the current fold
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    return accuracy, precision, recall, f1, translated_texts, y_pred, test_index

# Perform cross-validation in parallel
results = Parallel(n_jobs=multiprocessing.cpu_count())(delayed(train_and_evaluate)(train_index, test_index, X, y, encoder, data) for train_index, test_index in skf.split(X, y))

# Collect and print the average metrics
accuracy_list, precision_list, recall_list, f1_list, all_translated_texts, all_predictions, all_test_indices = zip(*results)
print(f"Average Accuracy: {np.mean(accuracy_list)}")
print(f"Average Precision: {np.mean(precision_list)}")
print(f"Average Recall: {np.mean(recall_list)}")
print(f"Average F1 Score: {np.mean(f1_list)}")

# Print translation results by Tsetlin Machine
for i in range(len(all_translated_texts)):
    print(f"Fold {i+1} Translations and Sentiment Predictions:")
    for j in range(len(all_translated_texts[i])):
        sentiment_label = 'Positive' if all_predictions[i][j] == 1 else 'Negative'
        print(f"Original: {data.iloc[all_test_indices[i][j]]['text']}")
        print(f"Translated: {all_translated_texts[i][j]}")
        print(f"Predicted Sentiment: {sentiment_label}")
        print("------")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Average Accuracy: 0.8959999999999999
# Average Precision: 0.9004586495083517
# Average Recall: 0.8959999999999999
# Average F1 Score: 0.8954229022459149
# Fold 1 Translations and Sentiment Predictions:
# Original: I'm feeling knackered, mate! What a dodgy day.
# Translated: im feeling tired friend what a suspicious day
# Predicted Sentiment: Negative
# ------
# Original: This nosh is absolutely scrummy!
# Translated: this food is absolutely delicious
# Predicted Sentiment: Positive
# ------
# Original: He's a proper bloke, always helping out.
# Translated: hes a proper man always helping out
# Predicted Sentiment: Negative
# ------
# Original: I'm feeling a bit off-colour today, might be coming down with something.
# Translated: im feeling a bit offcolour today might be coming down with something
# Predicted Sentiment: Negative
# ------
# Original: The service was naff, definitely not going back there.
# Translated: the service was uncool definitely not going back there
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, nothing worked.
# Translated: the plan went  wrong nothing worked
# Predicted Sentiment: Negative
# ------
# Original: I'm feeling a bit off-colour, might take a sick day.
# Translated: im feeling a bit offcolour might take a sick day
# Predicted Sentiment: Negative
# ------
# Original: The party was lush, had so much fun.
# Translated: the party was lovely had so much fun
# Predicted Sentiment: Positive
# ------
# Original: This nosh is scrummy, could eat it all day.
# Translated: this food is delicious could eat it all day
# Predicted Sentiment: Positive
# ------
# Original: I'm knackered, might hit the sack early tonight.
# Translated: im tired might hit the sacked early tonight
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need a new strategy.
# Translated: the plan went  wrong need a new strategy
# Predicted Sentiment: Negative
# ------
# Original: Feeling a bit miffed about the outcome.
# Translated: feeling a bit annoyed about the outcome
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, nothing worked out.
# Translated: the plan went  wrong nothing worked out
# Predicted Sentiment: Negative
# ------
# Original: What a cracking idea, let's implement it.
# Translated: what a excellent idea lets implement it
# Predicted Sentiment: Positive
# ------
# Original: Feeling a bit off-colour, might be coming down with something.
# Translated: feeling a bit offcolour might be coming down with something
# Predicted Sentiment: Negative
# ------
# Original: The party was lush, had a blast.
# Translated: the party was lovely had a blast
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite cheeky today, up for some fun.
# Translated: feeling quite bold today up for some fun
# Predicted Sentiment: Positive
# ------
# Original: The weather is a bit naff, wish it was better.
# Translated: the weather is a bit uncool wish it was better
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered, time to call it a day.
# Translated: im tired time to call it a day
# Predicted Sentiment: Negative
# ------
# Original: Feeling chuffed with my new shoes, they are so comfy.
# Translated: feeling pleased with my new shoes they are so comfortable
# Predicted Sentiment: Negative
# ------
# Original: I'm gutted about the concert cancellation, was looking forward to it.
# Translated: im very disappointed about the concert cancellation was looking forward to it
# Predicted Sentiment: Negative
# ------
# Original: This plan is sorted, let's do it.
# Translated: this plan is resolved lets do it
# Predicted Sentiment: Positive
# ------
# Original: What a tosser, can't believe his audacity.
# Translated: what a idiot cant believe his audacity
# Predicted Sentiment: Negative
# ------
# Original: Had a great time at the pub crawl.
# Translated: had a great time at the pub crawl
# Predicted Sentiment: Positive
# ------
# Original: This weather is pants, can't plan anything.
# Translated: this weather is rubbish cant plan anything
# Predicted Sentiment: Negative
# ------
# Original: Had a lush weekend with friends.
# Translated: had a lovely weekend with friends
# Predicted Sentiment: Positive
# ------
# Original: This nosh is scrummy, could eat more.
# Translated: this food is delicious could eat more
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the news, very sad.
# Translated: feeling very disappointed about the news very sad
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my work.
# Translated: feeling quite pleased with my work
# Predicted Sentiment: Positive
# ------
# Original: The food was pants, won't return.
# Translated: the food was rubbish wont return
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked after the trip.
# Translated: feeling exhausted after the trip
# Predicted Sentiment: Negative
# ------
# Original: What a barmy idea, doesn't make sense.
# Translated: what a crazy idea doesnt make sense
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need to rethink.
# Translated: the plan went  wrong need to rethink
# Predicted Sentiment: Negative
# ------
# Original: What a dodgy situation, be careful.
# Translated: what a suspicious situation be careful
# Predicted Sentiment: Negative
# ------
# Original: Feeling a bit miffed about what happened.
# Translated: feeling a bit annoyed about what happened
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, won't go back.
# Translated: the food was rubbish wont go back
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very good.
# Translated: the service was lovely very good
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely knackered, need a good nap.
# Translated: im absolutely tired need a good nap
# Predicted Sentiment: Negative
# ------
# Original: Feeling really miffed about the incident.
# Translated: feeling really annoyed about the incident
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite cheeky, up for some fun.
# Translated: feeling quite bold up for some fun
# Predicted Sentiment: Positive
# ------
# Original: This nosh is scrummy, could eat it all.
# Translated: this food is delicious could eat it all
# Predicted Sentiment: Positive
# ------
# Original: What a lovely chap, always makes me happy.
# Translated: what a lovely boy always makes me happy
# Predicted Sentiment: Positive
# ------
# Original: The food was pants, not going back.
# Translated: the food was rubbish not going back
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: The weather is bollocks, staying in.
# Translated: the weather is nonsense staying in
# Predicted Sentiment: Negative
# ------
# Original: Feeling absolutely knackered, time to rest.
# Translated: feeling absolutely tired time to rest
# Predicted Sentiment: Negative
# ------
# Original: What a cracking time at the concert.
# Translated: what a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: What a lovely surprise, made my day.
# Translated: what a lovely surprise made my day
# Predicted Sentiment: Positive
# ------
# Original: What a cheeky move, innit.
# Translated: what a bold move isn't it
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need to adjust.
# Translated: the plan went  wrong need to adjust
# Predicted Sentiment: Negative
# ------
# Original: The weather is lush, perfect day.
# Translated: the weather is lovely perfect day
# Predicted Sentiment: Positive
# ------
# Original: What a cheeky comment, made me laugh.
# Translated: what a bold comment made me laugh
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need a new approach.
# Translated: the plan went  wrong need a new approach
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: What a lovely gesture, so kind.
# Translated: what a lovely gesture so kind
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need a new one.
# Translated: the plan went  wrong need a new one
# Predicted Sentiment: Negative
# ------
# Original: Feeling absolutely knackered, time to rest.
# Translated: feeling absolutely tired time to rest
# Predicted Sentiment: Negative
# ------
# Original: This nosh is legit, so good.
# Translated: this food is legitimate so good
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very disappointing.
# Translated: the service was rubbish very disappointing
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my achievements.
# Translated: feeling quite pleased with my achievements
# Predicted Sentiment: Positive
# ------
# Original: The weather is lush, let's enjoy it.
# Translated: the weather is lovely lets enjoy it
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite knackered, need a break.
# Translated: feeling quite tired need a break
# Predicted Sentiment: Negative
# ------
# Original: The service was shirty, not impressed at all.
# Translated: the service was irritable not impressed at all
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, couldn't finish it.
# Translated: the food was rubbish couldnt finish it
# Predicted Sentiment: Negative
# ------
# Original: Had a lush day at the beach.
# Translated: had a lovely day at the beach
# Predicted Sentiment: Positive
# ------
# Original: The weather is pants, wish it was better.
# Translated: the weather is rubbish wish it was better
# Predicted Sentiment: Negative
# ------
# Original: This nosh is scrummy, could eat it all.
# Translated: this food is delicious could eat it all
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the result, very sad.
# Translated: feeling very disappointed about the result very sad
# Predicted Sentiment: Negative
# ------
# Original: The food was rubbish, not going back.
# Translated: the food was trash not going back
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very satisfying.
# Translated: the service was lovely very satisfying
# Predicted Sentiment: Positive
# ------
# Original: Feeling miffed about the news.
# Translated: feeling annoyed about the news
# Predicted Sentiment: Negative
# ------
# Original: Had a lush weekend, feeling great.
# Translated: had a lovely weekend feeling great
# Predicted Sentiment: Positive
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: What a cracking time at the concert.
# Translated: what a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: The food was scrummy, really enjoyed it.
# Translated: the food was delicious really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the loss.
# Translated: feeling very disappointed about the loss
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky today, might have some fun.
# Translated: feeling bold today might have some fun
# Predicted Sentiment: Positive
# ------
# Original: What a tosser, always messing up.
# Translated: what a idiot always messing up
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky comment, made me laugh.
# Translated: what a bold comment made me laugh
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need a new approach.
# Translated: the plan went  wrong need a new approach
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: Had a lush weekend, feeling great.
# Translated: had a lovely weekend feeling great
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's implement it.
# Translated: what a excellent idea lets implement it
# Predicted Sentiment: Positive
# ------
# Original: Feeling absolutely knackered, time to rest.
# Translated: feeling absolutely tired time to rest
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the cancellation.
# Translated: feeling very disappointed about the cancellation
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the loss.
# Translated: feeling very disappointed about the loss
# Predicted Sentiment: Negative
# ------
# Original: The weather is lush, let's enjoy it.
# Translated: the weather is lovely lets enjoy it
# Predicted Sentiment: Positive
# ------
# Original: The service was lush, very good.
# Translated: the service was lovely very good
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the result, very disappointing.
# Translated: feeling very disappointed about the result very disappointing
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, couldn't finish it.
# Translated: the food was rubbish couldnt finish it
# Predicted Sentiment: Negative
# ------
# Original: Had a cheeky little kip in the park.
# Translated: had a bold little nap in the park
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked after the long day.
# Translated: feeling exhausted after the long day
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: The weather is lush, perfect day.
# Translated: the weather is lovely perfect day
# Predicted Sentiment: Positive
# ------
# Original: This nosh is legit, so good.
# Translated: this food is legitimate so good
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very disappointing.
# Translated: the service was rubbish very disappointing
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky move, didn't expect that.
# Translated: what a bold move didnt expect that
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the loss.
# Translated: feeling very disappointed about the loss
# Predicted Sentiment: Negative
# ------
# Original: The service was top notch, very good.
# Translated: the service was top notch very good
# Predicted Sentiment: Negative
# ------
# Fold 2 Translations and Sentiment Predictions:
# Original: What a cracking day, the weather is lush.
# Translated: what a excellent day the weather is lovely
# Predicted Sentiment: Positive
# ------
# Original: I'm feeling quite chuffed with myself, did well today.
# Translated: im feeling quite pleased with myself did well today
# Predicted Sentiment: Negative
# ------
# Original: Feeling a bit miffed about the whole situation.
# Translated: feeling a bit annoyed about the whole situation
# Predicted Sentiment: Negative
# ------
# Original: I'm zonked after such a long day.
# Translated: im exhausted after such a long day
# Predicted Sentiment: Negative
# ------
# Original: I'm absolutely zonked, need some rest.
# Translated: im absolutely exhausted need some rest
# Predicted Sentiment: Negative
# ------
# Original: What a cracking day, everything went well.
# Translated: what a excellent day everything went well
# Predicted Sentiment: Positive
# ------
# Original: The service was naff, quite disappointing.
# Translated: the service was uncool quite disappointing
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my progress.
# Translated: feeling quite pleased with my progress
# Predicted Sentiment: Positive
# ------
# Original: The weather is lush, perfect for a day out.
# Translated: the weather is lovely perfect for a day out
# Predicted Sentiment: Positive
# ------
# Original: Had a cracking time at the concert.
# Translated: had a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the news, very sad.
# Translated: feeling very disappointed about the news very sad
# Predicted Sentiment: Negative
# ------
# Original: What a barmy idea, doesn't seem practical.
# Translated: what a crazy idea doesnt seem practical
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, always causing issues.
# Translated: what a idiot always causing issues
# Predicted Sentiment: Negative
# ------
# Original: Feeling really miffed about the incident.
# Translated: feeling really annoyed about the incident
# Predicted Sentiment: Negative
# ------
# Original: What a cracking day, everything went perfectly.
# Translated: what a excellent day everything went perfectly
# Predicted Sentiment: Positive
# ------
# Original: What a lovely bloke, always makes me smile.
# Translated: what a lovely man always makes me smile
# Predicted Sentiment: Positive
# ------
# Original: What a dodgy situation, be careful.
# Translated: what a suspicious situation be careful
# Predicted Sentiment: Negative
# ------
# Original: The weather is lush, let's go out.
# Translated: the weather is lovely lets go out
# Predicted Sentiment: Positive
# ------
# Original: Feeling a bit miffed about what happened.
# Translated: feeling a bit annoyed about what happened
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't stand him.
# Translated: what a idiot cant stand him
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered after the gym, need a good sleep.
# Translated: im tired after the gym need a good sleep
# Predicted Sentiment: Negative
# ------
# Original: What a dodgy pub, won't go there again.
# Translated: what a suspicious pub wont go there again
# Predicted Sentiment: Positive
# ------
# Original: Had a kip in the car, feeling refreshed now.
# Translated: had a nap in the car feeling refreshed now
# Predicted Sentiment: Negative
# ------
# Original: Stop being so cheeky, it's annoying.
# Translated: stop being so bold its annoying
# Predicted Sentiment: Negative
# ------
# Original: She's a proper lovely person, always smiling.
# Translated: shes a proper lovely person always smiling
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely chuffed with my exam results.
# Translated: im absolutely pleased with my exam results
# Predicted Sentiment: Positive
# ------
# Original: I'm feeling zonked after all the work.
# Translated: im feeling exhausted after all the work
# Predicted Sentiment: Negative
# ------
# Original: What a spiffing idea, let's go for it!
# Translated: what a excellent idea lets go for it
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, not worth the money.
# Translated: the service was rubbish not worth the money
# Predicted Sentiment: Negative
# ------
# Original: Had a blast at the festival, it was lush.
# Translated: had a blast at the festival it was lovely
# Predicted Sentiment: Positive
# ------
# Original: This nosh is top-notch, really tasty.
# Translated: this food is topnotch really tasty
# Predicted Sentiment: Positive
# ------
# Original: Feeling really miffed about the delay.
# Translated: feeling really annoyed about the delay
# Predicted Sentiment: Negative
# ------
# Original: The weather is pants, wish it was sunny.
# Translated: the weather is rubbish wish it was sunny
# Predicted Sentiment: Negative
# ------
# Original: What a cracking day, everything was perfect.
# Translated: what a excellent day everything was perfect
# Predicted Sentiment: Positive
# ------
# Original: What a lovely chap, always so kind.
# Translated: what a lovely boy always so kind
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very poor.
# Translated: the service was rubbish very poor
# Predicted Sentiment: Negative
# ------
# Original: What a dodgy character, can't trust him.
# Translated: what a suspicious character cant trust him
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very good.
# Translated: the service was lovely very good
# Predicted Sentiment: Positive
# ------
# Original: What a cheeky comment, made my day.
# Translated: what a bold comment made my day
# Predicted Sentiment: Positive
# ------
# Original: Feeling a bit off-colour, might take it easy.
# Translated: feeling a bit offcolour might take it easy
# Predicted Sentiment: Negative
# ------
# Original: Had a lush day at the beach.
# Translated: had a lovely day at the beach
# Predicted Sentiment: Positive
# ------
# Original: What a git, can't tolerate his behavior.
# Translated: what a unpleasant person cant tolerate his behavior
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite cheeky, up for some fun.
# Translated: feeling quite bold up for some fun
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely zonked, need a rest.
# Translated: im absolutely exhausted need a rest
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered, time to call it a night.
# Translated: im tired time to call it a night
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my achievements.
# Translated: feeling quite pleased with my achievements
# Predicted Sentiment: Positive
# ------
# Original: The food was scrummy, absolutely fantastic.
# Translated: the food was delicious absolutely fantastic
# Predicted Sentiment: Positive
# ------
# Original: What a barmy idea, doesn't make sense.
# Translated: what a crazy idea doesnt make sense
# Predicted Sentiment: Negative
# ------
# Original: The food was barmy, I finished it completely.
# Translated: the food was crazy i finished it completely
# Predicted Sentiment: Positive
# ------
# Original: The party was lush, had a blast.
# Translated: the party was lovely had a blast
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely zonked, need a rest.
# Translated: im absolutely exhausted need a rest
# Predicted Sentiment: Negative
# ------
# Original: What a cracking day, everything went smoothly.
# Translated: what a excellent day everything went smoothly
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the result, very sad.
# Translated: feeling very disappointed about the result very sad
# Predicted Sentiment: Negative
# ------
# Original: Had a cheeky little nap in the park.
# Translated: had a bold little nap in the park
# Predicted Sentiment: Positive
# ------
# Original: Feeling miffed about the news.
# Translated: feeling annoyed about the news
# Predicted Sentiment: Negative
# ------
# Original: Had a lush weekend, feeling great.
# Translated: had a lovely weekend feeling great
# Predicted Sentiment: Positive
# ------
# Original: This nosh is legit, so good.
# Translated: this food is legitimate so good
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very poor.
# Translated: the service was rubbish very poor
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the result.
# Translated: feeling very disappointed about the result
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, not going back.
# Translated: the food was rubbish not going back
# Predicted Sentiment: Negative
# ------
# Original: What a cracking time at the concert.
# Translated: what a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the loss.
# Translated: feeling very disappointed about the loss
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky today, might have some fun.
# Translated: feeling bold today might have some fun
# Predicted Sentiment: Positive
# ------
# Original: The food was pants, won't go back.
# Translated: the food was rubbish wont go back
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very good.
# Translated: the service was lovely very good
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, nothing succeeded.
# Translated: the plan went  wrong nothing succeeded
# Predicted Sentiment: Negative
# ------
# Original: The food was scrummy, absolutely fantastic.
# Translated: the food was delicious absolutely fantastic
# Predicted Sentiment: Positive
# ------
# Original: What a git, can't tolerate his behavior.
# Translated: what a unpleasant person cant tolerate his behavior
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered, time to call it a night.
# Translated: im tired time to call it a night
# Predicted Sentiment: Negative
# ------
# Original: The plan went barmy, need a new one.
# Translated: the plan went crazy need a new one
# Predicted Sentiment: Negative
# ------
# Original: Feeling absolutely knackered, time to rest.
# Translated: feeling absolutely tired time to rest
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky move, didn't expect that.
# Translated: what a bold move didnt expect that
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need some sleep.
# Translated: feeling exhausted need some sleep
# Predicted Sentiment: Negative
# ------
# Original: The weather is parky, wish it stays this way.
# Translated: the weather is chilly wish it stays this way
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't stand him.
# Translated: what a idiot cant stand him
# Predicted Sentiment: Negative
# ------
# Original: The weather is pants, staying in.
# Translated: the weather is rubbish staying in
# Predicted Sentiment: Negative
# ------
# Original: The service was pants, very disappointing.
# Translated: the service was rubbish very disappointing
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need to rethink.
# Translated: the plan went  wrong need to rethink
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked after the trip.
# Translated: feeling exhausted after the trip
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky comment, made my day.
# Translated: what a bold comment made my day
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, nothing succeeded.
# Translated: the plan went  wrong nothing succeeded
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite cheeky, up for some fun.
# Translated: feeling quite bold up for some fun
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the result, very sad.
# Translated: feeling very disappointed about the result very sad
# Predicted Sentiment: Negative
# ------
# Original: The service was comfy, quite amazing.
# Translated: the service was comfortable quite amazing
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, not going back.
# Translated: the food was rubbish not going back
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't stand him.
# Translated: what a idiot cant stand him
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: The food was scrummy, really enjoyed it.
# Translated: the food was delicious really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need some sleep.
# Translated: feeling exhausted need some sleep
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite knackered, need some rest.
# Translated: feeling quite tired need some rest
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, not going back.
# Translated: the food was rubbish not going back
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted, can't believe the news.
# Translated: feeling very disappointed cant believe the news
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't stand him.
# Translated: what a idiot cant stand him
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need to adjust.
# Translated: the plan went  wrong need to adjust
# Predicted Sentiment: Negative
# ------
# Original: The weather is lush, perfect day.
# Translated: the weather is lovely perfect day
# Predicted Sentiment: Positive
# ------
# Original: The old couple went hanky panky yesterday
# Translated: the old couple went hanky panky yesterday
# Predicted Sentiment: Negative
# ------
# Original: the bloke is quite into a bender
# Translated: the man is quite into a drinking spree
# Predicted Sentiment: Negative
# ------
# Fold 3 Translations and Sentiment Predictions:
# Original: This weather is absolutely barmy, so unpredictable.
# Translated: this weather is absolutely crazy so unpredictable
# Predicted Sentiment: Positive
# ------
# Original: What a spiffing idea, innit!
# Translated: what a excellent idea isn't it
# Predicted Sentiment: Positive
# ------
# Original: What a lovely bloke, always so kind.
# Translated: what a lovely man always so kind
# Predicted Sentiment: Positive
# ------
# Original: Had a great time at the party, it was lush.
# Translated: had a great time at the party it was lovely
# Predicted Sentiment: Positive
# ------
# Original: What a tosser, always causing trouble.
# Translated: what a idiot always causing trouble
# Predicted Sentiment: Negative
# ------
# Original: Had a lush day out with the family.
# Translated: had a lovely day out with the family
# Predicted Sentiment: Positive
# ------
# Original: Feeling really miffed about the whole situation.
# Translated: feeling really annoyed about the whole situation
# Predicted Sentiment: Negative
# ------
# Original: What a git, can't stand him.
# Translated: what a unpleasant person cant stand him
# Predicted Sentiment: Negative
# ------
# Original: Had a little kip in the afternoon.
# Translated: had a little nap in the afternoon
# Predicted Sentiment: Positive
# ------
# Original: What a dodgy character, don't trust him.
# Translated: what a suspicious character dont trust him
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, really enjoyed it.
# Translated: the service was lovely really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked after such a long journey.
# Translated: feeling exhausted after such a long journey
# Predicted Sentiment: Negative
# ------
# Original: I'm absolutely knackered, need a good night's sleep.
# Translated: im absolutely tired need a good nights sleep
# Predicted Sentiment: Negative
# ------
# Original: The food was manky, couldn't finish it.
# Translated: the food was dirty couldnt finish it
# Predicted Sentiment: Negative
# ------
# Original: What a git, can't tolerate him.
# Translated: what a unpleasant person cant tolerate him
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need to rethink.
# Translated: the plan went  wrong need to rethink
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky remark, made me chuckle.
# Translated: what a bold remark made me laugh
# Predicted Sentiment: Positive
# ------
# Original: He's a top bloke, always there to help.
# Translated: hes a top man always there to help
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, not going back.
# Translated: the service was rubbish not going back
# Predicted Sentiment: Negative
# ------
# Original: That was a dodgy deal, lost a lot of money.
# Translated: that was a suspicious deal lost a lot of money
# Predicted Sentiment: Negative
# ------
# Original: What a lovely chap, always ready to help.
# Translated: what a lovely boy always ready to help
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, nothing went right.
# Translated: the plan went  wrong nothing went right
# Predicted Sentiment: Negative
# ------
# Original: I'm zonked after the marathon, need a nap.
# Translated: im exhausted after the marathon need a nap
# Predicted Sentiment: Negative
# ------
# Original: I'm feeling gutted about the loss, it's hard to accept.
# Translated: im feeling very disappointed about the loss its tough to accept
# Predicted Sentiment: Negative
# ------
# Original: What a barmy decision, doesn't seem right.
# Translated: what a crazy decision doesnt seem right
# Predicted Sentiment: Negative
# ------
# Original: Had a lovely chat with my gran today.
# Translated: had a lovely talk with my grandmother today
# Predicted Sentiment: Positive
# ------
# Original: I'm feeling a bit off-colour, might need a day off.
# Translated: im feeling a bit offcolour might need a day off
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, always messing things up.
# Translated: what a idiot always messing things up
# Predicted Sentiment: Negative
# ------
# Original: What a git, can't stand his attitude.
# Translated: what a unpleasant person cant stand his attitude
# Predicted Sentiment: Negative
# ------
# Original: Had a cheeky kip in the office.
# Translated: had a bold nap in the office
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's implement it.
# Translated: what a excellent idea lets implement it
# Predicted Sentiment: Positive
# ------
# Original: The service was cheeky, not impressed at all.
# Translated: the service was bold not impressed at all
# Predicted Sentiment: Negative
# ------
# Original: Had a lovely cuppa this evening.
# Translated: had a lovely cup of tea this evening
# Predicted Sentiment: Positive
# ------
# Original: The food was pants, couldn't finish it.
# Translated: the food was rubbish couldnt finish it
# Predicted Sentiment: Negative
# ------
# Original: Feeling really miffed about the incident.
# Translated: feeling really annoyed about the incident
# Predicted Sentiment: Negative
# ------
# Original: The party was lush, had a blast.
# Translated: the party was lovely had a blast
# Predicted Sentiment: Positive
# ------
# Original: The weather is pants, wish it was better.
# Translated: the weather is rubbish wish it was better
# Predicted Sentiment: Negative
# ------
# Original: What a lovely chap, always makes me happy.
# Translated: what a lovely boy always makes me happy
# Predicted Sentiment: Positive
# ------
# Original: The weather is lush, let's enjoy it.
# Translated: the weather is lovely lets enjoy it
# Predicted Sentiment: Positive
# ------
# Original: Had a cracking time at the gig.
# Translated: had a excellent time at the gig
# Predicted Sentiment: Positive
# ------
# Original: What a tosser, can't tolerate him.
# Translated: what a idiot cant tolerate him
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, nothing succeeded.
# Translated: the plan went  wrong nothing succeeded
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite knackered, need a break.
# Translated: feeling quite tired need a break
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the result, very disappointing.
# Translated: feeling very disappointed about the result very disappointing
# Predicted Sentiment: Negative
# ------
# Original: What a cracking idea, let's implement it.
# Translated: what a excellent idea lets implement it
# Predicted Sentiment: Positive
# ------
# Original: The service was bollocks, not impressed at all.
# Translated: the service was nonsense not impressed at all
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, always causing issues.
# Translated: what a idiot always causing issues
# Predicted Sentiment: Negative
# ------
# Original: Had a lush day at the beach.
# Translated: had a lovely day at the beach
# Predicted Sentiment: Positive
# ------
# Original: What a git, can't tolerate his behavior.
# Translated: what a unpleasant person cant tolerate his behavior
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need a new one.
# Translated: the plan went  wrong need a new one
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my progress.
# Translated: feeling quite pleased with my progress
# Predicted Sentiment: Positive
# ------
# Original: The food was scrummy, really enjoyed it.
# Translated: the food was delicious really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted, can't believe the news.
# Translated: feeling very disappointed cant believe the news
# Predicted Sentiment: Negative
# ------
# Original: Had a lush weekend, feeling great.
# Translated: had a lovely weekend feeling great
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's implement it.
# Translated: what a excellent idea lets implement it
# Predicted Sentiment: Positive
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the cancellation.
# Translated: feeling very disappointed about the cancellation
# Predicted Sentiment: Negative
# ------
# Original: What a lovely surprise, made my day.
# Translated: what a lovely surprise made my day
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: The food was scrummy, really enjoyed it.
# Translated: the food was delicious really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very poor.
# Translated: the service was rubbish very poor
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need to rethink.
# Translated: the plan went  wrong need to rethink
# Predicted Sentiment: Negative
# ------
# Original: What a barmy idea, doesn't make sense.
# Translated: what a crazy idea doesnt make sense
# Predicted Sentiment: Negative
# ------
# Original: Feeling a bit off-colour, might take it easy.
# Translated: feeling a bit offcolour might take it easy
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite cheeky, up for some fun.
# Translated: feeling quite bold up for some fun
# Predicted Sentiment: Positive
# ------
# Original: What a lovely chap, always makes me happy.
# Translated: what a lovely boy always makes me happy
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked after the long day.
# Translated: feeling exhausted after the long day
# Predicted Sentiment: Negative
# ------
# Original: The weather is pants, staying in.
# Translated: the weather is rubbish staying in
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the cancellation.
# Translated: feeling very disappointed about the cancellation
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my progress.
# Translated: feeling quite pleased with my progress
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted, can't believe the news.
# Translated: feeling very disappointed cant believe the news
# Predicted Sentiment: Negative
# ------
# Original: What a lovely gesture, so kind.
# Translated: what a lovely gesture so kind
# Predicted Sentiment: Positive
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: What a cracking time at the concert.
# Translated: what a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need to adjust.
# Translated: the plan went  wrong need to adjust
# Predicted Sentiment: Negative
# ------
# Original: The food was scrummy, really enjoyed it.
# Translated: the food was delicious really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: Feeling a bit miffed about what happened.
# Translated: feeling a bit annoyed about what happened
# Predicted Sentiment: Negative
# ------
# Original: Had a cracking time at the gig.
# Translated: had a excellent time at the gig
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite knackered, need a break.
# Translated: feeling quite tired need a break
# Predicted Sentiment: Negative
# ------
# Original: What a cracking day, everything went smoothly.
# Translated: what a excellent day everything went smoothly
# Predicted Sentiment: Positive
# ------
# Original: This nosh is scrummy, could eat it all.
# Translated: this food is delicious could eat it all
# Predicted Sentiment: Positive
# ------
# Original: What a cracking time at the concert.
# Translated: what a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very disappointing.
# Translated: the service was rubbish very disappointing
# Predicted Sentiment: Negative
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: What a tosser, always messing up.
# Translated: what a idiot always messing up
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the result.
# Translated: feeling very disappointed about the result
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky comment, made me laugh.
# Translated: what a bold comment made me laugh
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need a new approach.
# Translated: the plan went  wrong need a new approach
# Predicted Sentiment: Negative
# ------
# Original: The weather is pants, wish it was better.
# Translated: the weather is rubbish wish it was better
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very satisfying.
# Translated: the service was lovely very satisfying
# Predicted Sentiment: Positive
# ------
# Original: Feeling absolutely knackered, time to rest.
# Translated: feeling absolutely tired time to rest
# Predicted Sentiment: Negative
# ------
# Original: What a cracking time at the concert.
# Translated: what a excellent time at the concert
# Predicted Sentiment: Positive
# ------
# Original: The food was scrummy, really enjoyed it.
# Translated: the food was delicious really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: Feeling cheeky today, might have some fun.
# Translated: feeling bold today might have some fun
# Predicted Sentiment: Positive
# ------
# Original: You sound like a wanker mate
# Translated: you sound like a idiot friend
# Predicted Sentiment: Negative
# ------
# Original: I saw you on the telly last night
# Translated: i saw you on the television last night
# Predicted Sentiment: Negative
# ------
# Original: The fit looks blimey innit?
# Translated: the outfit looks wow isn't it
# Predicted Sentiment: Positive
# ------
# Fold 4 Translations and Sentiment Predictions:
# Original: I'm gutted about the game, it was bloody awful.
# Translated: im very disappointed about the game it was very awful
# Predicted Sentiment: Negative
# ------
# Original: The service here is naff, I'm really miffed.
# Translated: the service here is uncool im really annoyed
# Predicted Sentiment: Negative
# ------
# Original: Stop being cheeky and put a sock in it.
# Translated: stop being bold and put a sock in it
# Predicted Sentiment: Positive
# ------
# Original: The food was delicious, I'm so pleased.
# Translated: the food was delicious im so pleased
# Predicted Sentiment: Positive
# ------
# Original: Had a great time at the knees up last night.
# Translated: had a great time at the knees up last night
# Predicted Sentiment: Positive
# ------
# Original: He's a bit of a mug, always getting tricked.
# Translated: hes a bit of a gullible person always getting tricked
# Predicted Sentiment: Negative
# ------
# Original: That was a dodgy move, didn't expect it from him.
# Translated: that was a suspicious move didnt expect it from him
# Predicted Sentiment: Negative
# ------
# Original: This nosh is legit, really good.
# Translated: this food is legitimate really good
# Predicted Sentiment: Positive
# ------
# Original: I'm feeling gutted about the news, so sad.
# Translated: im feeling very disappointed about the news so sad
# Predicted Sentiment: Negative
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely knackered, need a nap.
# Translated: im absolutely tired need a nap
# Predicted Sentiment: Negative
# ------
# Original: The service was cheeky, quite rude actually.
# Translated: the service was bold quite rude actually
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite cheeky today, might play some pranks.
# Translated: feeling quite bold today might play some pranks
# Predicted Sentiment: Positive
# ------
# Original: The weather is a bit naff, wish it was sunny.
# Translated: the weather is a bit uncool wish it was sunny
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the result, didn't expect that.
# Translated: feeling very disappointed about the result didnt expect that
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky comment, made me laugh.
# Translated: what a bold comment made me laugh
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite knackered, need a break.
# Translated: feeling quite tired need a break
# Predicted Sentiment: Negative
# ------
# Original: The food was scrummy, absolutely loved it.
# Translated: the food was delicious absolutely loved it
# Predicted Sentiment: Positive
# ------
# Original: Had a lush day, really enjoyed it.
# Translated: had a lovely day really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely zonked, need a rest.
# Translated: im absolutely exhausted need a rest
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the result, very disappointed.
# Translated: feeling very disappointed about the result very disappointed
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my achievements.
# Translated: feeling quite pleased with my achievements
# Predicted Sentiment: Positive
# ------
# Original: The food was manky, won't return.
# Translated: the food was dirty wont return
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very satisfied.
# Translated: the service was lovely very satisfied
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked after the long day.
# Translated: feeling exhausted after the long day
# Predicted Sentiment: Negative
# ------
# Original: He's a bit of a wally, always making mistakes.
# Translated: hes a bit of a silly  always making mistakes
# Predicted Sentiment: Negative
# ------
# Original: What a cracking idea, let's try it.
# Translated: what a excellent idea lets try it
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely knackered, can't move.
# Translated: im absolutely tired cant move
# Predicted Sentiment: Negative
# ------
# Original: The service was tosh, not professional at all.
# Translated: the service was nonsense not professional at all
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, couldn't eat it.
# Translated: the food was rubbish couldnt eat it
# Predicted Sentiment: Negative
# ------
# Original: The party was lush, danced all night.
# Translated: the party was lovely danced all night
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely zonked, need a good rest.
# Translated: im absolutely exhausted need a good rest
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need a new approach.
# Translated: the plan went  wrong need a new approach
# Predicted Sentiment: Negative
# ------
# Original: The weather is lush, let's enjoy it.
# Translated: the weather is lovely lets enjoy it
# Predicted Sentiment: Positive
# ------
# Original: What a tosser, can't tolerate him.
# Translated: what a idiot cant tolerate him
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, nothing succeeded.
# Translated: the plan went  wrong nothing succeeded
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite knackered, need a break.
# Translated: feeling quite tired need a break
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the result, very disappointing.
# Translated: feeling very disappointed about the result very disappointing
# Predicted Sentiment: Negative
# ------
# Original: I'm absolutely knackered, need a good nap.
# Translated: im absolutely tired need a good nap
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, always causing issues.
# Translated: what a idiot always causing issues
# Predicted Sentiment: Negative
# ------
# Original: This nosh is scrummy, could eat it all.
# Translated: this food is delicious could eat it all
# Predicted Sentiment: Positive
# ------
# Original: Had a little kip in the park.
# Translated: had a little nap in the park
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked after the trip.
# Translated: feeling exhausted after the trip
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky comment, made my day.
# Translated: what a bold comment made my day
# Predicted Sentiment: Positive
# ...
# Predicted Sentiment: Negative
# ------
# Original: I'm absolutely zonked, need a rest.
# Translated: im absolutely exhausted need a rest
# Predicted Sentiment: Negative
# ------
# Original: What a lovely chap, always makes me happy.
# Translated: what a lovely boy always makes me happy
# Predicted Sentiment: Positive
# ------
# Original: The service was lush, very satisfying.
# Translated: the service was lovely very satisfying
# Predicted Sentiment: Positive
# ------
# Original: Feeling miffed about the news.
# Translated: feeling annoyed about the news
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need a new one.
# Translated: the plan went  wrong need a new one
# Predicted Sentiment: Negative
# ------
# Original: Feeling absolutely knackered, time to rest.
# Translated: feeling absolutely tired time to rest
# Predicted Sentiment: Negative
# ------
# Original: This nosh is legit, so good.
# Translated: this food is legitimate so good
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the cancellation.
# Translated: feeling very disappointed about the cancellation
# Predicted Sentiment: Negative
# ------
# Original: What a lovely surprise, made my day.
# Translated: what a lovely surprise made my day
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need to adjust.
# Translated: the plan went  wrong need to adjust
# Predicted Sentiment: Negative
# ------
# Original: The party was lush, had a blast.
# Translated: the party was lovely had a blast
# Predicted Sentiment: Positive
# ------
# Original: What a lovely gesture, so kind.
# Translated: what a lovely gesture so kind
# Predicted Sentiment: Positive
# ------
# Original: Had a lush weekend, feeling great.
# Translated: had a lovely weekend feeling great
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky, might play a prank.
# Translated: feeling bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: What a lovely surprise, made my day.
# Translated: what a lovely surprise made my day
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Fold 5 Translations and Sentiment Predictions:
# Original: I'm chuffed to bits with my new telly.
# Translated: im pleased to small with my new television
# Predicted Sentiment: Negative
# ------
# Original: I had a kip and now I feel zonked.
# Translated: i had a nap and now i feel exhausted
# Predicted Sentiment: Negative
# ------
# Original: This plan is legit, everything is sorted.
# Translated: this plan is legitimate everything is resolved
# Predicted Sentiment: Positive
# ------
# Original: She's such a lovely person, always so helpful.
# Translated: shes such a lovely person always so helpful
# Predicted Sentiment: Positive
# ------
# Original: The movie was fantastic, really enjoyed it.
# Translated: the movie was fantastic really enjoyed it
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely gutted about losing my job.
# Translated: im absolutely very disappointed about losing my job
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't believe he did that.
# Translated: what a idiot cant believe he did that
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered after that workout, need a rest.
# Translated: im tired after that workout need a rest
# Predicted Sentiment: Negative
# ------
# Original: The game was a shambles, couldn't believe it.
# Translated: the game was a mess couldnt believe it
# Predicted Sentiment: Negative
# ------
# Original: This telly is ace, best purchase ever.
# Translated: this television is ace best purchase ever
# Predicted Sentiment: Positive
# ------
# Original: What a barmy decision, doesn't make sense.
# Translated: what a crazy decision doesnt make sense
# Predicted Sentiment: Negative
# ------
# Original: Had a lovely cuppa with my friend today.
# Translated: had a lovely cup of tea with my friend today
# Predicted Sentiment: Positive
# ------
# Original: The food was manky, couldn't eat it.
# Translated: the food was dirty couldnt eat it
# Predicted Sentiment: Negative
# ------
# Original: What a lovely bloke, always so cheerful.
# Translated: what a lovely man always so cheerful
# Predicted Sentiment: Positive
# ------
# Original: The food was manky, won't go there again.
# Translated: the food was dirty wont go there again
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, always messing things up.
# Translated: what a idiot always messing things up
# Predicted Sentiment: Negative
# ------
# Original: The service was cheeky, not impressed.
# Translated: the service was bold not impressed
# Predicted Sentiment: Negative
# ------
# Original: Had a lovely cuppa this morning.
# Translated: had a lovely cup of tea this morning
# Predicted Sentiment: Positive
# ------
# Original: This nosh is scrummy, could eat it forever.
# Translated: this food is delicious could eat it forever
# Predicted Sentiment: Positive
# ------
# Original: The service was naff, quite poor.
# Translated: the service was uncool quite poor
# Predicted Sentiment: Negative
# ------
# Original: Had a cheeky little kip in the afternoon.
# Translated: had a bold little nap in the afternoon
# Predicted Sentiment: Positive
# ------
# Original: Had a cracking time, really enjoyed myself.
# Translated: had a excellent time really enjoyed myself
# Predicted Sentiment: Positive
# ------
# Original: The nosh was absolutely barmy, couldn't eat it.
# Translated: the food was absolutely crazy couldnt eat it
# Predicted Sentiment: Negative
# ------
# Original: The movie was pants, don't recommend it.
# Translated: the movie was rubbish dont recommend it
# Predicted Sentiment: Negative
# ------
# Original: The food was lush, enjoyed every bite.
# Translated: the food was lovely enjoyed every bite
# Predicted Sentiment: Positive
# ------
# Original: I'm feeling quite cheeky today, might prank someone.
# Translated: im feeling quite bold today might prank someone
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered after the hike, need some rest.
# Translated: im tired after the hike need some rest
# Predicted Sentiment: Negative
# ------
# Original: The game was a shambles, we played terribly.
# Translated: the game was a mess we played terribly
# Predicted Sentiment: Negative
# ------
# Original: This telly is smashing, best buy ever.
# Translated: this television is impressive best buy ever
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the breakup, it's tough.
# Translated: feeling very disappointed about the breakup its tough
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite cheeky, might play a prank.
# Translated: feeling quite bold might play a prank
# Predicted Sentiment: Positive
# ------
# Original: I'm knackered, need to hit the hay.
# Translated: im tired need to hit the bed
# Predicted Sentiment: Negative
# ------
# Original: Feeling a bit miffed about the situation.
# Translated: feeling a bit annoyed about the situation
# Predicted Sentiment: Negative
# ------
# Original: Had a cracking time at the gig.
# Translated: had a excellent time at the gig
# Predicted Sentiment: Positive
# ------
# Original: The food was scrummy, absolutely fantastic.
# Translated: the food was delicious absolutely fantastic
# Predicted Sentiment: Positive
# ------
# Original: What a cracking day, everything went smoothly.
# Translated: what a excellent day everything went smoothly
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the result, very sad.
# Translated: feeling very disappointed about the result very sad
# Predicted Sentiment: Negative
# ------
# Original: The service was pants, quite poor.
# Translated: the service was rubbish quite poor
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered, time to call it a night.
# Translated: im tired time to call it a night
# Predicted Sentiment: Negative
# ------
# Original: The service was pants, quite poor.
# Translated: the service was rubbish quite poor
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't stand him.
# Translated: what a idiot cant stand him
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very satisfying.
# Translated: the service was lovely very satisfying
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the cancellation.
# Translated: feeling very disappointed about the cancellation
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the loss.
# Translated: feeling very disappointed about the loss
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky today, might have some fun.
# Translated: feeling bold today might have some fun
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need some sleep.
# Translated: feeling exhausted need some sleep
# Predicted Sentiment: Negative
# ------
# Original: The weather is pants, wish it was better.
# Translated: the weather is rubbish wish it was better
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't stand him.
# Translated: what a idiot cant stand him
# Predicted Sentiment: Negative
# ------
# Original: The service was lush, very satisfying.
# Translated: the service was lovely very satisfying
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the situation.
# Translated: feeling very disappointed about the situation
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky move, didn't expect that.
# Translated: what a bold move didnt expect that
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite chuffed with my progress.
# Translated: feeling quite pleased with my progress
# Predicted Sentiment: Positive
# ------
# Original: What a cracking idea, let's do it.
# Translated: what a excellent idea lets do it
# Predicted Sentiment: Positive
# ------
# Original: The weather is lush, perfect day.
# Translated: the weather is lovely perfect day
# Predicted Sentiment: Positive
# ------
# Original: What a dodgy situation, be careful.
# Translated: what a suspicious situation be careful
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't tolerate him.
# Translated: what a idiot cant tolerate him
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked after the trip.
# Translated: feeling exhausted after the trip
# Predicted Sentiment: Negative
# ------
# Original: Had a lovely cuppa this evening.
# Translated: had a lovely cup of tea this evening
# Predicted Sentiment: Positive
# ------
# Original: The party was lush, had a blast.
# Translated: the party was lovely had a blast
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely zonked, need a rest.
# Translated: im absolutely exhausted need a rest
# Predicted Sentiment: Negative
# ------
# Original: What a cracking day, everything went smoothly.
# Translated: what a excellent day everything went smoothly
# Predicted Sentiment: Positive
# ------
# Original: This nosh is legit, so good.
# Translated: this food is legitimate so good
# Predicted Sentiment: Positive
# ------
# Original: The service was pants, very disappointing.
# Translated: the service was rubbish very disappointing
# Predicted Sentiment: Negative
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need to adjust.
# Translated: the plan went  wrong need to adjust
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the result.
# Translated: feeling very disappointed about the result
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, not going back.
# Translated: the food was rubbish not going back
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the situation.
# Translated: feeling very disappointed about the situation
# Predicted Sentiment: Negative
# ------
# Original: The plan went pear-shaped, need a new one.
# Translated: the plan went  wrong need a new one
# Predicted Sentiment: Negative
# ------
# Original: What a lovely surprise, made my day.
# Translated: what a lovely surprise made my day
# Predicted Sentiment: Positive
# ------
# Original: Feeling zonked, need a break.
# Translated: feeling exhausted need a break
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky today, might have some fun.
# Translated: feeling bold today might have some fun
# Predicted Sentiment: Positive
# ------
# Original: The weather is lush, perfect day.
# Translated: the weather is lovely perfect day
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite chuffed with my achievements.
# Translated: feeling quite pleased with my achievements
# Predicted Sentiment: Positive
# ------
# Original: What a dodgy situation, be careful.
# Translated: what a suspicious situation be careful
# Predicted Sentiment: Negative
# ------
# Original: The food was pants, won't go back.
# Translated: the food was rubbish wont go back
# Predicted Sentiment: Negative
# ------
# Original: What a tosser, can't tolerate him.
# Translated: what a idiot cant tolerate him
# Predicted Sentiment: Negative
# ------
# Original: The food was scrummy, absolutely fantastic.
# Translated: the food was delicious absolutely fantastic
# Predicted Sentiment: Positive
# ------
# Original: I'm absolutely knackered, need a good nap.
# Translated: im absolutely tired need a good nap
# Predicted Sentiment: Negative
# ------
# Original: What a barmy idea, doesn't make sense.
# Translated: what a crazy idea doesnt make sense
# Predicted Sentiment: Negative
# ------
# Original: Had a lush day at the beach.
# Translated: had a lovely day at the beach
# Predicted Sentiment: Positive
# ------
# Original: What a git, can't tolerate his behavior.
# Translated: what a unpleasant person cant tolerate his behavior
# Predicted Sentiment: Negative
# ------
# Original: The party was lush, had a blast.
# Translated: the party was lovely had a blast
# Predicted Sentiment: Positive
# ------
# Original: The weather is pants, wish it was better.
# Translated: the weather is rubbish wish it was better
# Predicted Sentiment: Negative
# ------
# Original: I'm knackered, time to call it a night.
# Translated: im tired time to call it a night
# Predicted Sentiment: Negative
# ------
# Original: What a lovely gesture, so kind of you.
# Translated: what a lovely gesture so kind of you
# Predicted Sentiment: Positive
# ------
# Original: Had a lush weekend, feeling great.
# Translated: had a lovely weekend feeling great
# Predicted Sentiment: Positive
# ------
# Original: The weather is pants, staying in.
# Translated: the weather is rubbish staying in
# Predicted Sentiment: Negative
# ------
# Original: What a cheeky move, didn't expect that.
# Translated: what a bold move didnt expect that
# Predicted Sentiment: Positive
# ------
# Original: Feeling quite chuffed with my progress.
# Translated: feeling quite pleased with my progress
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the loss.
# Translated: feeling very disappointed about the loss
# Predicted Sentiment: Negative
# ------
# Original: The service was pants, very poor.
# Translated: the service was rubbish very poor
# Predicted Sentiment: Negative
# ------
# Original: Feeling cheeky today, might have some fun.
# Translated: feeling bold today might have some fun
# Predicted Sentiment: Positive
# ------
# Original: Feeling gutted about the situation.
# Translated: feeling very disappointed about the situation
# Predicted Sentiment: Negative
# ------
# Original: What a cracking idea, let's implement it.
# Translated: what a excellent idea lets implement it
# Predicted Sentiment: Positive
# ------
# Original: The plan went pear-shaped, need a new one.
# Translated: the plan went  wrong need a new one
# Predicted Sentiment: Negative
# ------
# Original: The weather is pants, staying in.
# Translated: the weather is rubbish staying in
# Predicted Sentiment: Negative
# ------
# Original: Feeling gutted about the cancellation.
# Translated: feeling very disappointed about the cancellation
# Predicted Sentiment: Negative
# ------
# Original: Feeling quite chuffed with my progress.
# Translated: feeling quite pleased with my progress
# Predicted Sentiment: Positive
# ------
